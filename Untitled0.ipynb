# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input

# =========================
# DATASET
# =========================
X, y = make_classification(n_samples=400, n_features=20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# =========================
# REPRESENTACIÓN
# =========================
def create_individual():
    num_layers = random.randint(1, 3)
    return [random.randint(10, 100) for _ in range(num_layers)]

# =========================
# MODELO
# =========================
def build_model(chromosome):
    model = Sequential()

    # Capa de entrada (forma correcta)
    model.add(Input(shape=(20,)))

    # Primera capa oculta
    model.add(Dense(chromosome[0], activation='relu'))

    # Capas ocultas adicionales
    for n in chromosome[1:]:
        model.add(Dense(n, activation='relu'))

    # Capa de salida
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# =========================
# FITNESS
# =========================
def fitness(individual):
    model = build_model(individual)
    model.fit(X_train, y_train, epochs=3, batch_size=16, verbose=0)
    y_pred = (model.predict(X_val, verbose=0) > 0.5).astype(int)
    return accuracy_score(y_val, y_pred)

# =========================
# SELECCIÓN
# =========================
def selection(population, scores):
    i, j = random.sample(range(len(population)), 2)
    return population[i] if scores[i] > scores[j] else population[j]

# =========================
# CRUZAMIENTO
# =========================
def crossover(p1, p2):
    min_len = min(len(p1), len(p2))
    if min_len < 2:
        return p1.copy()
    cut = random.randint(1, min_len - 1)
    return p1[:cut] + p2[cut:]

# =========================
# MUTACIÓN
# =========================
def mutation(ind):
    if random.random() < 0.3:
        idx = random.randint(0, len(ind)-1)
        ind[idx] = random.randint(10, 100)
    return ind

# =========================
# VISUALIZACIÓN POBLACIÓN
# =========================
def print_population(pop, scores, gen):
    print(f"\n===== GENERACIÓN {gen} =====")
    print("ID | Cromosoma        | Fitness")
    print("--------------------------------")
    for i, (ind, sc) in enumerate(zip(pop, scores)):
        print(f"{i:<2} | {str(ind):<15} | {sc:.4f}")

# =========================
# ALGORITMO GENÉTICO
# =========================
pop_size = 5
generations = 8

population = [create_individual() for _ in range(pop_size)]

best_history = []
avg_history = []

plt.ion()

for gen in range(1, generations+1):

    # Evaluación
    scores = [fitness(ind) for ind in population]

    print_population(population, scores, gen)

    best_history.append(max(scores))
    avg_history.append(np.mean(scores))

    # Nueva población
    new_pop = []

    print("\n--- REPRODUCCIÓN ---")

    while len(new_pop) < pop_size:
        p1 = selection(population, scores)
        p2 = selection(population, scores)

        print(f"\nPadre 1: {p1}")
        print(f"Padre 2: {p2}")

        # Cruzamiento
        child = crossover(p1, p2)
        print(f"Hijo (crossover): {child}")

        # Mutación
        child = mutation(child)
        print(f"Hijo (mutado): {child}")

        new_pop.append(child)

    population = new_pop

    # =========================
    # GRÁFICA EN TIEMPO REAL
    # =========================
    plt.clf()
    plt.plot(best_history, label="Mejor fitness")
    plt.plot(avg_history, label="Promedio fitness")
    plt.xlabel("Generación")
    plt.ylabel("Fitness")
    plt.title("Evolución del Algoritmo Genético")
    plt.legend()
    plt.pause(0.5)

plt.ioff()
plt.show()
# Out:
# ===== GENERACIÓN 1 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [19, 95]        | 0.8500
# 1  | [98]            | 0.8875
# 2  | [29, 78]        | 0.8625
# 3  | [56, 73, 54]    | 0.9375
# 4  | [74, 54, 58]    | 0.9125
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [74, 54, 58]
# Padre 2: [98]
# Hijo (crossover): [74, 54, 58]
# Hijo (mutado): [74, 54, 58]
#
# Padre 1: [29, 78]
# Padre 2: [56, 73, 54]
# Hijo (crossover): [29, 73, 54]
# Hijo (mutado): [29, 73, 54]
#
# Padre 1: [56, 73, 54]
# Padre 2: [56, 73, 54]
# Hijo (crossover): [56, 73, 54]
# Hijo (mutado): [56, 73, 54]
#
# Padre 1: [29, 78]
# Padre 2: [56, 73, 54]
# Hijo (crossover): [29, 73, 54]
# Hijo (mutado): [29, 73, 54]
#
# Padre 1: [74, 54, 58]
# Padre 2: [74, 54, 58]
# Hijo (crossover): [74, 54, 58]
# Hijo (mutado): [74, 54, 58]
# ===== GENERACIÓN 2 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [74, 54, 58]    | 0.9000
# 1  | [29, 73, 54]    | 0.8875
# 2  | [56, 73, 54]    | 0.8750
# 3  | [29, 73, 54]    | 0.9000
# 4  | [74, 54, 58]    | 0.8875
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [74, 54, 58]
# Padre 2: [74, 54, 58]
# Hijo (crossover): [74, 54, 58]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [74, 54, 58]
# Padre 2: [29, 73, 54]
# Hijo (crossover): [74, 73, 54]
# Hijo (mutado): [62, 73, 54]
#
# Padre 1: [74, 54, 58]
# Padre 2: [29, 73, 54]
# Hijo (crossover): [74, 73, 54]
# Hijo (mutado): [74, 73, 70]
#
# Padre 1: [29, 73, 54]
# Padre 2: [29, 73, 54]
# Hijo (crossover): [29, 73, 54]
# Hijo (mutado): [29, 73, 45]
#
# Padre 1: [74, 54, 58]
# Padre 2: [29, 73, 54]
# Hijo (crossover): [74, 54, 54]
# Hijo (mutado): [58, 54, 54]
# ===== GENERACIÓN 3 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [74, 54, 85]    | 0.9375
# 1  | [62, 73, 54]    | 0.9250
# 2  | [74, 73, 70]    | 0.9250
# 3  | [29, 73, 45]    | 0.8625
# 4  | [58, 54, 54]    | 0.8750
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [62, 73, 54]
# Padre 2: [74, 73, 70]
# Hijo (crossover): [62, 73, 70]
# Hijo (mutado): [62, 73, 70]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [62, 73, 54]
# Padre 2: [74, 73, 70]
# Hijo (crossover): [62, 73, 70]
# Hijo (mutado): [62, 73, 70]
#
# Padre 1: [74, 73, 70]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
# ===== GENERACIÓN 4 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [62, 73, 70]    | 0.9250
# 1  | [74, 54, 85]    | 0.9125
# 2  | [74, 54, 85]    | 0.9000
# 3  | [62, 73, 70]    | 0.8875
# 4  | [74, 54, 85]    | 0.9375
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [62, 73, 70]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
#
# Padre 1: [62, 73, 70]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
#
# Padre 1: [62, 73, 70]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 65]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [50, 54, 85]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 50, 85]
# ===== GENERACIÓN 5 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [62, 54, 85]    | 0.9250
# 1  | [62, 54, 85]    | 0.9125
# 2  | [62, 54, 65]    | 0.9250
# 3  | [50, 54, 85]    | 0.9000
# 4  | [74, 50, 85]    | 0.9250
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [62, 54, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
#
# Padre 1: [74, 50, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [74, 50, 85]
# Hijo (mutado): [74, 50, 85]
#
# Padre 1: [62, 54, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
#
# Padre 1: [74, 50, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [62, 54, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
# ===== GENERACIÓN 6 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [62, 54, 85]    | 0.8875
# 1  | [74, 50, 85]    | 0.9500
# 2  | [62, 54, 85]    | 0.9500
# 3  | [74, 54, 85]    | 0.9125
# 4  | [62, 54, 85]    | 0.9375
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [74, 50, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [62, 54, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 54, 85]
#
# Padre 1: [74, 50, 85]
# Padre 2: [74, 54, 85]
# Hijo (crossover): [74, 50, 85]
# Hijo (mutado): [74, 50, 10]
#
# Padre 1: [62, 54, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [62, 54, 85]
# Hijo (mutado): [62, 32, 85]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 50, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [47, 54, 85]
# ===== GENERACIÓN 7 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [74, 54, 85]    | 0.9000
# 1  | [62, 54, 85]    | 0.9625
# 2  | [74, 50, 10]    | 0.9375
# 3  | [62, 32, 85]    | 0.8875
# 4  | [47, 54, 85]    | 0.8250
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [74, 50, 10]
# Padre 2: [74, 50, 10]
# Hijo (crossover): [74, 50, 10]
# Hijo (mutado): [15, 50, 10]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 50, 10]
# Hijo (crossover): [74, 54, 10]
# Hijo (mutado): [74, 54, 52]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 50, 10]
# Hijo (crossover): [74, 54, 10]
# Hijo (mutado): [74, 54, 10]
#
# Padre 1: [74, 54, 85]
# Padre 2: [62, 54, 85]
# Hijo (crossover): [74, 54, 85]
# Hijo (mutado): [74, 54, 85]
#
# Padre 1: [62, 54, 85]
# Padre 2: [74, 50, 10]
# Hijo (crossover): [62, 54, 10]
# Hijo (mutado): [62, 54, 10]
# ===== GENERACIÓN 8 =====
# ID | Cromosoma        | Fitness
# --------------------------------
# 0  | [15, 50, 10]    | 0.6375
# 1  | [74, 54, 52]    | 0.9375
# 2  | [74, 54, 10]    | 0.9000
# 3  | [74, 54, 85]    | 0.9125
# 4  | [62, 54, 10]    | 0.8500
#
# --- REPRODUCCIÓN ---
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 10]
# Hijo (crossover): [74, 54, 10]
# Hijo (mutado): [74, 54, 10]
#
# Padre 1: [74, 54, 85]
# Padre 2: [74, 54, 52]
# Hijo (crossover): [74, 54, 52]
# Hijo (mutado): [74, 54, 52]
#
# Padre 1: [74, 54, 52]
# Padre 2: [74, 54, 52]
# Hijo (crossover): [74, 54, 52]
# Hijo (mutado): [37, 54, 52]
#
# Padre 1: [74, 54, 10]
# Padre 2: [74, 54, 52]
# Hijo (crossover): [74, 54, 52]
# Hijo (mutado): [74, 54, 52]
#
# Padre 1: [62, 54, 10]
# Padre 2: [62, 54, 10]
# Hijo (crossover): [62, 54, 10]
# Hijo (mutado): [62, 54, 10]

# %%
from tensorflow.keras import backend as K

def fitness(individual, verbose_metrics=False):
    K.clear_session()

    model = build_model(individual)

    history = model.fit(
        X_train, y_train,
        epochs=5,
        batch_size=16,
        validation_data=(X_val, y_val),
        verbose=0
    )

    # Predicción final
    y_pred = (model.predict(X_val, verbose=0) > 0.5).astype(int)
    acc = accuracy_score(y_val, y_pred)

    # 🔍 Mostrar métricas si se desea
    if verbose_metrics:
        print("\nEntrenamiento del individuo:", individual)
        print("Epoch | Train Acc | Val Acc | Train Loss | Val Loss")

        for i in range(len(history.history['accuracy'])):
            print(f"{i+1:5} | "
                  f"{history.history['accuracy'][i]:.4f} | "
                  f"{history.history['val_accuracy'][i]:.4f} | "
                  f"{history.history['loss'][i]:.4f} | "
                  f"{history.history['val_loss'][i]:.4f}")

    return acc, history.history
